# %% [markdown]
# The purpose of this file is to show how to read Excel worksheets into python

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
#read the dataframe 
bp = pd.read_excel('bp-energy-outlook-2020-summary-tables.xlsx')

# %% [markdown]
# Readint eh excel worksheet allows creating a dataframe with index and name of all worksheets inside the workbook as below

# %%
# get the names of sheets in the excel file
bp['bp Energy Outlook 2050: September 2020'].tolist()
# Out:
# ['This workbook contains information presented in the ',
#  '2020 edition of the bp Energy Outlook 2050 ',
#  'which can be found on the internet at:',
#  'http://www.bp.com/energyoutlook',
#  'These summary data tables are sourced from the Business-as-usual, Rapid and Net Zero scenarios',
#  'Please use these links or the tabs at the bottom to navigate between the tables.',
#  'Consumption',
#  'Primary',
#  'Oil - EJ',
#  'Oil - Mbd',
#  'Biofuels - EJ',
#  'Biofuels - Mbd',
#  'Gas - EJ',
#  'Gas - Bcm',
#  'Coal - EJ',
#  'Nuclear - EJ',
#  'Hydro - EJ',
#  'Bioenergy - EJ',
#  'Solar - EJ',
#  'Wind -EJ',
#  'Renewables - EJ',
#  'Production',
#  'Oil Production - EJ',
#  'Oil Production - Mbd',
#  'Natural gas Production - EJ',
#  'Natural gas Production - Bcm',
#  'Coal Production - EJ',
#  'Energy carriers',
#  'Power and Hydrogen',
#  'Regional insights data tables',
#  'World',
#  'United States',
#  'Brazil',
#  'EU',
#  'Russia',
#  'Middle East',
#  'Africa',
# ...

# %%
# define country list available in the report
country_list = ['World',
 'United States',
 'Brazil',
 'EU',
 'Russia',
 'Middle East',
 'Africa',
 'China',
 'India',
 'Other Asia']

# %%
#read specific worjsheet from the excel workbook
xls = pd.ExcelFile('bp-energy-outlook-2020-summary-tables.xlsx')
brazil = pd.read_excel(xls, 'Brazil')

# %%
brazil.head(50)
# Out:
#                                       Back to content  Unnamed: 1  Unnamed: 2  \
# 0                                              Brazil         NaN         NaN
# 1                                                 NaN         NaN         NaN
# 2                           EJ unless otherwise noted     1995.00     2000.00
# 3                                        Consumption          NaN         NaN
# 4                                              Brazil        6.72        8.03
# 5                                               Fuels         NaN         NaN
# 6                                                 Oil        3.14        3.73
# 7                                        Natural gas+        0.19        0.35
# 8                                                Coal        0.50        0.54
# 9                                             Nuclear        0.03        0.06
# 10                                              Hydro        2.54        3.04
# ...

# %%
#columns are define in the third column of index [2]
brazil.iloc[2].tolist()
# Out:
# ['EJ unless otherwise noted',
#  1995.0,
#  2000.0,
#  2005.0,
#  2010.0,
#  2015.0,
#  2018.0,
#  '1995-2018',
#  nan,
#  2025,
#  2030.0,
#  2035.0,
#  2040.0,
#  2045.0,
#  2050.0,
#  '2018-2050',
#  nan,
#  2025,
#  2030.0,
#  2035.0,
#  2040.0,
#  2045.0,
#  2050.0,
#  '2018-2050',
#  nan,
#  2025,
#  2030.0,
#  2035.0,
#  2040.0,
#  2045.0,
#  2050.0,
#  '2018-2050']

# %%
# get the names of sectors covered in the report to be used in defining sectors of interest
brazil['Back to content'].tolist()
# Out:
# ['Brazil',
#  nan,
#  'EJ unless otherwise noted',
#  'Consumption ',
#  'Brazil',
#  'Fuels',
#  'Oil',
#  'Natural gas+',
#  'Coal',
#  'Nuclear',
#  'Hydro',
#  'Renewables*',
#  nan,
#  'Oil (Mbd)',
#  'Natural gas+ (Bcm)',
#  nan,
#  'Sectors^',
#  'Transport',
#  'Industry',
#  'Non-combusted',
#  'Buildings',
#  nan,
#  'Inputs to power',
#  nan,
#  'Production',
#  'Oil',
#  'Natural gas+',
#  'Coal',
#  nan,
#  'Oil (Mbd)',
#  'Natural gas+ (Bcm)',
#  nan,
#  'Emissions',
#  'Net CO2 emissions (Mt)',
#  '^Includes electricity and hydrogen; and their associated conversion losses.',
#  '*Renewables include wind, solar, geothermal, biomass, biomethane and biofuels.',
#  '+Natural gas does not include biomethane.']

# %%
sectors_int = ['Oil',
 'Natural gas+',
 'Coal',
 'Nuclear',
 'Hydro',
 'Renewables*',
 'Oil (Mbd)',
 'Natural gas+ (Bcm)',
 'Transport',
 'Industry',
 'Non-combusted',
 'Buildings',
 'Inputs to power',
 'Oil',
 'Natural gas+',
 'Coal',
 'Oil (Mbd)',
 'Natural gas+ (Bcm)',
 'Net CO2 emissions (Mt)']

# %%
brazil.columns =['sector', '1995',
 '2000',
 '2005',
 '2010',
 '2015',
 '2018',
 '1995-2018',
 'empty1',
 '2025 Rapid scenario',
 '2030 Rapid scenario',
 '2035 Rapid scenario',
 '2040 Rapid scenario',
 '2045 Rapid scenario',
 '2050 Rapid scenario',
 '2018-2050',
 'empty2',
 '2025 Net Zero scenario',
 '2030 Net Zero scenario',
 '2035 Net Zero scenario',
 '2040 Net Zero scenario',
 '2045 Net Zero scenario',
 '2050 Net Zero scenario',
 '2018-2050',
 'empty3',
 '2025 Bussiness as susual',
 '2030 Bussiness as susual',
 '2035 Bussiness as susual',
 '2040 Bussiness as susual',
 '2045 Bussiness as susual',
 '2050 Bussiness as susual',
 '2018-2050']

# %%
brazil.head(30)
# Out:
#                        sector     1995     2000     2005     2010     2015  \
# 0                      Brazil      NaN      NaN      NaN      NaN      NaN
# 1                         NaN      NaN      NaN      NaN      NaN      NaN
# 2   EJ unless otherwise noted  1995.00  2000.00  2005.00  2010.00  2015.00
# 3                Consumption       NaN      NaN      NaN      NaN      NaN
# 4                      Brazil     6.72     8.03     8.85    10.99    12.24
# 5                       Fuels      NaN      NaN      NaN      NaN      NaN
# 6                         Oil     3.14     3.73     3.82     4.63     5.15
# 7                Natural gas+     0.19     0.35     0.72     0.99     1.55
# 8                        Coal     0.50     0.54     0.54     0.61     0.74
# 9                     Nuclear     0.03     0.06     0.10     0.14     0.13
# 10                      Hydro     2.54     3.04     3.27     3.79     3.28
# ...

# %%
# identify the index values of production and consumption data to erase confusion 
consumption_inx = [6,7,8,9,10,11,13,14]
production_inx = [25,26,27,29,30]
idx_list = [6,7,8,9,10,11,13,14, 25,26,27,29,30]

# %%
#drop the empty rows
brazil.drop(['empty1', 'empty2', 'empty3'], axis = 1, inplace = True)

# %%
brazil_clean = brazil[brazil['sector'].isin(sectors_int)]

# %%
"""
def replace_vals(df, indx, text):
   
    #input : df
    #input : index of values where the cahnge will take place as a list
    #input : text want to be added next to the value of interest
    #output: adjustment of the values
    
    
    for x in list_defined:
        brazil_clean.loc[x,'sector'] = brazil_clean.loc[x,'sector']+text
"""
# Out:
# "\ndef replace_vals(df, indx, text):\n   \n    #input : df\n    #input : index of values where the cahnge will take place as a list\n    #input : text want to be added next to the value of interest\n    #output: adjustment of the values\n    \n    \n    for x in list_defined:\n        brazil_clean.loc[x,'sector'] = brazil_clean.loc[x,'sector']+text\n"

# %%
def replace_vals_(df, indx):
    """
    input : df
    input : index of values where the cahnge will take place as a list
    output: adjustment of the values
    
    """
    for x in indx:
        if x<15:
            brazil_clean.loc[x,'sector'] = brazil_clean.loc[x,'sector']+' consumption'
        if x>15:
            brazil_clean.loc[x,'sector'] = brazil_clean.loc[x,'sector']+' production'

# %%
replace_vals_(brazil_clean, idx_list)
# Out:
# C:\Users\M.Amer\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
brazil_clean
# Out:
#                             sector    1995    2000    2005    2010    2015  \
# 6                  Oil consumption    3.14    3.73    3.82    4.63    5.15
# 7         Natural gas+ consumption    0.19    0.35    0.72    0.99    1.55
# 8                 Coal consumption    0.50    0.54    0.54    0.61    0.74
# 9              Nuclear consumption    0.03    0.06    0.10    0.14    0.13
# 10               Hydro consumption    2.54    3.04    3.27    3.79    3.28
# 11         Renewables* consumption    0.32    0.31    0.40    0.83    1.39
# 13           Oil (Mbd) consumption    1.57    1.85    1.91    2.32    2.59
# 14  Natural gas+ (Bcm) consumption    5.23    9.70   20.13   27.58   42.94
# 17                       Transport    1.81    2.16    2.43    3.29    3.94
# 18                        Industry    2.82    3.33    3.82    4.50    4.64
# 19                   Non-combusted    0.40    0.44    0.39    0.57    0.50
# ...
